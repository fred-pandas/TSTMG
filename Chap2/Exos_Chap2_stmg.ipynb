# %% [markdown]
# # Exo n°2

# %%
X = [0, 2, 4, 6, 7, 8]
Y = [36, 41, 45, 49, 52, 53]

sum(X) / 6, sum(Y) / 6

# %% [markdown]
# # Exo n°4

# %%
import numpy as np

X = [0, 1, 2, 3, 4, 5]
Y = [42, 35, 28, 17, 13, 9]

np.polyfit(X, Y, 1)

# %% [markdown]
# # Exo n°5

# %%
import numpy as np

X = [0, 1, 2, 3, 4, 5, 6, 7]
Y = [613, 646, 673, 704, 719, 747, 777, 808]

a, b = np.polyfit(X, Y, 1)
a, b

# %% [markdown]
# Représentons le nuage de points et la droite de regression

# %%
import pylab as pl

fig, ax = pl.subplots()
ax.plot(X, Y, 'o', color = 'blue')
ax.plot([0, 7], [a * 0 + b, a * 7 + b], color = 'red')
pl.show()

# %% [markdown]
# # Exo n°6

# %%
import numpy as np

X = list(range(13))
Y = [1083, 1125, 1159, 1183, 1225, 1270,1370, 1385, 1497, 1503, 1508, 1554, 1617]

sum(X) / len(X), sum(Y) /len(Y)

# %%
import numpy

a, b = np.polyfit(X, Y, 1)
a, b

# %%
46 * 14 + 1068.8
